# %% [markdown]
# # **Make Pretrained-Model FaceNet !**

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (2) 미션2
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (3) 미션3
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project4 폴더를 만드세요.
#         * 데이터 파일을 복사해 넣습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project4'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
## colab에서 세션 재시작을 요구하는 팝업이 뜨면 재시작 누르세요.
# !pip install keras-nightly
# Out:
# Collecting keras-nightly
#   Downloading keras_nightly-3.7.0.dev2024102803-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras-nightly) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly) (0.1.2)
# Downloading keras_nightly-3.7.0.dev2024102803-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.0 MB/s eta 0:00:00
# Installing collected packages: keras-nightly
# Successfully installed keras-nightly-3.7.0.dev2024102803

# %% [markdown]
# ## 3.미션1

# %% [markdown]
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (1) 데이터셋 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 데이터셋을 불러옵니다.
#         - 데이터셋은 두 개의 압축 파일이어야 합니다.
#             1. lfw-deepfunneled.zip : Labeled Faces in the Wild 데이터셋
#             2. 여러분의 얼굴 이미지 데이터셋
#                 - 여러분의 얼굴 이미지가 담긴 **압축 파일**을 **Google Drive에 업로드** 하기를 권장합니다.
#                     - 이미지 파일 하나하나 업로드 하면 시간이 오래 걸립니다.
#     - 데이터셋 압축 파일을 **Colab에 폴더를 생성한 후 해제**하세요.
#         - 데이터셋 폴더를 **본인 얼굴 폴더, LFW 폴더로 나누어** 생성하는 것을 권장합니다.
#         - 만일 두 압축 파일을 하나의 폴더에 모두 해제하면 전처리가 더 까다로워질 것입니다.
#     - 예시 코드에서 사용한 라이브러리
#         - os, zipfile

# %% [markdown]
# #### 1) 본인 얼굴 이미지 데이터셋 불러오기

# %%
import os
import zipfile

# %%
data_myFace = path + '/Keras/my_face_512_5000.zip'
data_myFace
# Out:
# '/content/drive/MyDrive/project4/Keras/my_face_512_5000.zip'

# %%
## Colab에 생성할 본인 얼굴 폴더 경로
extract_folder = '/content/my_face'

## 위의 경로에 폴더가 없을 때 생성
if not os.path.exists(extract_folder) :
    os.makedirs(extract_folder)

## 위의 경로에 압축을 해제
with zipfile.ZipFile(data_myFace, 'r') as zip_ref :
    file_list = zip_ref.namelist()

    for f in file_list :
        if not f.endswith('/') and f.lower().endswith('.jpg') :
            file_name = os.path.basename(f)

            if not file_name.startswith('._') :
                d_path = os.path.join(extract_folder, file_name)

                with zip_ref.open(f) as source, open(d_path, 'wb') as target :
                    target.write(source.read())

# %%
## 생성된 본인 얼굴 이미지 데이터 폴더 안의 이미지 수
len(os.listdir(extract_folder) )
# Out:
# 4796

# %% [markdown]
# #### 2) 다른 얼굴 이미지 데이터셋 불러오기

# %%
data_other = path + '/Keras/lfw-deepfunneled.zip'
data_other
# Out:
# '/content/drive/MyDrive/project4/Keras/lfw-deepfunneled.zip'

# %%
## Colab에 생성할 다른 얼굴 폴더 경로
extract_folder = '/content/other_face'

## 위의 경로에 폴더가 없을 때 생성
if not os.path.exists(extract_folder) :
    os.makedirs(extract_folder)

## 위의 경로에 압축을 해제
with zipfile.ZipFile(data_other, 'r') as zip_ref :
    file_list = zip_ref.namelist()

    for f in file_list :
        if not f.endswith('/') and f.lower().endswith('.jpg') :
            file_name = os.path.basename(f)

            if not file_name.startswith('._') :
                d_path = os.path.join(extract_folder, file_name)

                with zip_ref.open(f) as source, open(d_path, 'wb') as target :
                    target.write(source.read())

# %%
## 생성된 다른 사람 얼굴 이미지 데이터 폴더 안의 이미지 수
len(os.listdir(extract_folder) )
# Out:
# 13233

# %% [markdown]
# ### (2) 데이터셋 전처리
# * **세부 요구사항**
#     - 데이터셋을 전처리 합니다.
#         - Training set, Validation set, Test set으로 데이터셋을 나누어 주세요.
#             - 학습 과정에서 Training set, Validation set을 사용해야 합니다.
#             - 추론 과정에서 Test set을 사용해야 합니다.
#         - Keras의 **특정 함수**가 실제 존재하는 이미지 파일에 대한 전처리를 쉽게 도와줍니다.
#         - **특정 함수**에서 요구하는 폴더 구조가 있습니다. **특정 함수**를 사용한다면 이에 맞춰서 폴더를 생성해야 합니다.
#         - 각 데이터셋에 스케일링도 적용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - glob, random, shutil, numpy, keras

# %% [markdown]
# #### 1) 데이터셋 분할

# %%
import glob
import random
import shutil
import numpy as np

from keras.utils import load_img, img_to_array
from keras.utils import image_dataset_from_directory

# %%
## image_dataset_from_directory를 사용하기 위해 Colab에 폴더 생성

## 생성될 폴더의 경로
tr_data = '/content/tr_data'
te_data = '/content/te_data'

## 폴더가 존재하지 않을 때 폴더를 생성
if not os.path.exists(tr_data) :
    os.makedirs(tr_data)

if not os.path.exists(te_data) :
    os.makedirs(te_data)

## 폴더 생성 확인
print(os.path.exists(tr_data) )
print(os.path.exists(te_data) )
# Out:
# True
# True

# %%
## Keras의 image_dataset_from_directory를 사용하기 위해 Colab에 하위 폴더 생성

## 생성될 폴더에 대한 하위 폴더 생성
class_names = ['my', 'other']

for cn in class_names :
    temp = os.path.join(tr_data, cn)

    if not os.path.exists( temp ) :
        os.makedirs(temp)

    ## 폴더 생성 확인
    print(os.path.exists(temp))

for cn in class_names :
    temp = os.path.join(te_data, cn)

    if not os.path.exists( temp ) :
        os.makedirs(temp)

    ## 폴더 생성 확인
    print(os.path.exists(temp))
# Out:
# True
# True
# True
# True

# %%
## 본인 얼굴 데이터가 있는 폴더 경로의 파일 전체를 정렬하여 리스트화
img_list_my = sorted(glob.glob('/content/my_face/*',))

## 다른 얼굴 데이터가 있는 폴더 경로의 파일 전체를 정렬하여 리스트화
img_list_other = sorted(glob.glob('/content/other_face/*'))

## 이미지 갯수 확인
len(img_list_my), len(img_list_other)
# Out:
# (4796, 13233)

# %%
## 얼굴 데이터를 Training set, Test set으로 분할하기 위한 사전 작업
## 분할 재현성을 위한 난수 고정
random.seed(2024)
random.shuffle(img_list_my)
random.shuffle(img_list_other)

img_list_my[:5], img_list_other[:5]
# Out:
# (['/content/my_face/my_face_3287.jpg',
#   '/content/my_face/my_face_1121.jpg',
#   '/content/my_face/my_face_1105.jpg',
#   '/content/my_face/my_face_198.jpg',
#   '/content/my_face/my_face_2929.jpg'],
#  ['/content/other_face/Steven_Curtis_Chapman_0001.jpg',
#   '/content/other_face/Robert_Downey_Jr_0001.jpg',
#   '/content/other_face/Guillermo_Coria_0002.jpg',
#   '/content/other_face/Raul_Mondesi_0001.jpg',
#   '/content/other_face/Scott_McClellan_0003.jpg'])

# %%
## Test set의 비율 설정
test_size = 0.2

## 나의 얼굴 파일 리스트와 다른 얼굴 파일 리스트에 대한 반복문
for i_l in [img_list_my, img_list_other] :
    ## 리스트의 길이 체크
    list_len = 4796  ## 예시 파일의 이미지 갯수가 맞지 않아서 4796개까지만 사용
    ## 데이터 분할을 위한 인덱스 설정
    split_idx = int(list_len * (1 - test_size) )

    ## 인덱스를 이용해 상위 리스트를 Training set, Test set 2가지로 세분화
    list_tr = i_l[ : split_idx]
    list_te = i_l[split_idx : list_len]

    ## 현재 리스트가 나의 얼굴 파일 리스트와 같다면
    if i_l == img_list_my :
        ## "나의 얼굴 파일 리스트"의 파일을 Training set 폴더 안의 "나의 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_tr :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=tr_data+'/my/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

        ## "나의 얼굴 파일 리스트"의 파일을 Test set 폴더 안의 "나의 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_te :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=te_data+'/my/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

    ## 현재 리스트가 "나의 얼굴 파일 리스트"가 아니라면 (즉, "다른 사람 얼굴 파일 리스트"라면)
    else :
        ## "다른 사람 얼굴 파일 리스트"의 파일을 Training set 폴더 안의 "다른 사람 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_tr :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=tr_data+'/other/'+f_name[-1],
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

        ## "다른 사람 얼굴 파일 리스트"의 파일을 Test set 폴더 안의 "다른 사람 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_te :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=te_data+'/other/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 파일 이동 완료 : my_face_4583.jpg
# 파일 이동 완료 : my_face_380.jpg
# 파일 이동 완료 : my_face_2254.jpg
# 파일 이동 완료 : my_face_4799.jpg
# 파일 이동 완료 : my_face_2956.jpg
# 파일 이동 완료 : my_face_3372.jpg
# 파일 이동 완료 : my_face_3602.jpg
# 파일 이동 완료 : my_face_1189.jpg
# 파일 이동 완료 : my_face_2356.jpg
# 파일 이동 완료 : my_face_202.jpg
# 파일 이동 완료 : my_face_1509.jpg
# 파일 이동 완료 : my_face_432.jpg
# 파일 이동 완료 : my_face_1822.jpg
# 파일 이동 완료 : my_face_956.jpg
# 파일 이동 완료 : my_face_2226.jpg
# 파일 이동 완료 : my_face_2981.jpg
# 파일 이동 완료 : my_face_743.jpg
# 파일 이동 완료 : my_face_3617.jpg
# 파일 이동 완료 : my_face_4910.jpg
# 파일 이동 완료 : my_face_108.jpg
# 파일 이동 완료 : my_face_3559.jpg
# 파일 이동 완료 : my_face_4324.jpg
# 파일 이동 완료 : my_face_1374.jpg
# 파일 이동 완료 : my_face_70.jpg
# 파일 이동 완료 : my_face_4809.jpg
# 파일 이동 완료 : my_face_754.jpg
# 파일 이동 완료 : my_face_4571.jpg
# 파일 이동 완료 : my_face_2657.jpg
# 파일 이동 완료 : my_face_128.jpg
# 파일 이동 완료 : my_face_4232.jpg
# 파일 이동 완료 : my_face_4889.jpg
# 파일 이동 완료 : my_face_2730.jpg
# 파일 이동 완료 : my_face_1020.jpg
# 파일 이동 완료 : my_face_3583.jpg
# 파일 이동 완료 : my_face_1911.jpg
# 파일 이동 완료 : my_face_1110.jpg
# 파일 이동 완료 : my_face_4501.jpg
# 파일 이동 완료 : my_face_3750.jpg
# 파일 이동 완료 : my_face_2389.jpg
# 파일 이동 완료 : my_face_2520.jpg
# 파일 이동 완료 : my_face_4069.jpg
# 파일 이동 완료 : my_face_3404.jpg
# 파일 이동 완료 : my_face_2246.jpg
# 파일 이동 완료 : my_face_2622.jpg
# 파일 이동 완료 : my_face_2023.jpg
# 파일 이동 완료 : my_face_4225.jpg
# 파일 이동 완료 : my_face_4453.jpg
# 파일 이동 완료 : my_face_4086.jpg
# 파일 이동 완료 : my_face_2683.jpg
# 파일 이동 완료 : my_face_4381.jpg
# 파일 이동 완료 : my_face_4491.jpg
# 파일 이동 완료 : my_face_3112.jpg
# 파일 이동 완료 : my_face_3419.jpg
# 파일 이동 완료 : my_face_4633.jpg
# 파일 이동 완료 : my_face_244.jpg
# 파일 이동 완료 : my_face_4544.jpg
# 파일 이동 완료 : my_face_2469.jpg
# 파일 이동 완료 : my_face_2607.jpg
# 파일 이동 완료 : my_face_2627.jpg
# 파일 이동 완료 : my_face_1793.jpg
# 파일 이동 완료 : my_face_1460.jpg
# 파일 이동 완료 : my_face_241.jpg
# 파일 이동 완료 : my_face_1214.jpg
# 파일 이동 완료 : my_face_3174.jpg
# 파일 이동 완료 : my_face_1940.jpg
# 파일 이동 완료 : my_face_1002.jpg
# 파일 이동 완료 : my_face_3427.jpg
# 파일 이동 완료 : my_face_679.jpg
# 파일 이동 완료 : my_face_2392.jpg
# 파일 이동 완료 : my_face_799.jpg
# 파일 이동 완료 : my_face_1826.jpg
# 파일 이동 완료 : my_face_1224.jpg
# 파일 이동 완료 : my_face_812.jpg
# 파일 이동 완료 : my_face_1797.jpg
# 파일 이동 완료 : my_face_1959.jpg
# 파일 이동 완료 : my_face_1658.jpg
# 파일 이동 완료 : my_face_2259.jpg
# 파일 이동 완료 : my_face_2281.jpg
# 파일 이동 완료 : my_face_4747.jpg
# 파일 이동 완료 : my_face_2832.jpg
# 파일 이동 완료 : my_face_929.jpg
# 파일 이동 완료 : my_face_4867.jpg
# 파일 이동 완료 : my_face_167.jpg
# 파일 이동 완료 : my_face_2628.jpg
# 파일 이동 완료 : my_face_1960.jpg
# 파일 이동 완료 : my_face_4970.jpg
# 파일 이동 완료 : my_face_1418.jpg
# 파일 이동 완료 : my_face_278.jpg
# 파일 이동 완료 : my_face_1906.jpg
# 파일 이동 완료 : my_face_1558.jpg
# 파일 이동 완료 : my_face_3912.jpg
# 파일 이동 완료 : my_face_678.jpg
# 파일 이동 완료 : my_face_134.jpg
# 파일 이동 완료 : my_face_3734.jpg
# 파일 이동 완료 : my_face_3468.jpg
# 파일 이동 완료 : my_face_2732.jpg
# 파일 이동 완료 : my_face_4951.jpg
# 파일 이동 완료 : my_face_2364.jpg
# 파일 이동 완료 : my_face_400.jpg
# 파일 이동 완료 : my_face_251.jpg
# 파일 이동 완료 : my_face_2697.jpg
# 파일 이동 완료 : my_face_480.jpg
# 파일 이동 완료 : my_face_177.jpg
# 파일 이동 완료 : my_face_988.jpg
# 파일 이동 완료 : my_face_2938.jpg
# 파일 이동 완료 : my_face_835.jpg
# 파일 이동 완료 : my_face_2039.jpg
# 파일 이동 완료 : my_face_3155.jpg
# 파일 이동 완료 : my_face_3335.jpg
# 파일 이동 완료 : my_face_3326.jpg
# 파일 이동 완료 : my_face_1536.jpg
# 파일 이동 완료 : my_face_2550.jpg
# 파일 이동 완료 : my_face_4199.jpg
# 파일 이동 완료 : my_face_4358.jpg
# 파일 이동 완료 : my_face_516.jpg
# 파일 이동 완료 : my_face_4700.jpg
# 파일 이동 완료 : my_face_3042.jpg
# 파일 이동 완료 : my_face_4545.jpg
# 파일 이동 완료 : my_face_2856.jpg
# 파일 이동 완료 : my_face_3199.jpg
# 파일 이동 완료 : my_face_2510.jpg
# 파일 이동 완료 : my_face_1618.jpg
# 파일 이동 완료 : my_face_2772.jpg
# 파일 이동 완료 : my_face_3695.jpg
# 파일 이동 완료 : my_face_2827.jpg
# 파일 이동 완료 : my_face_4374.jpg
# 파일 이동 완료 : my_face_2173.jpg
# 파일 이동 완료 : my_face_1031.jpg
# 파일 이동 완료 : my_face_2346.jpg
# 파일 이동 완료 : my_face_1747.jpg
# 파일 이동 완료 : my_face_1493.jpg
# 파일 이동 완료 : my_face_26.jpg
# 파일 이동 완료 : my_face_3557.jpg
# 파일 이동 완료 : my_face_2010.jpg
# 파일 이동 완료 : my_face_2317.jpg
# 파일 이동 완료 : my_face_4573.jpg
# 파일 이동 완료 : my_face_3584.jpg
# 파일 이동 완료 : my_face_3597.jpg
# 파일 이동 완료 : my_face_399.jpg
# 파일 이동 완료 : my_face_303.jpg
# 파일 이동 완료 : my_face_2091.jpg
# 파일 이동 완료 : my_face_4786.jpg
# 파일 이동 완료 : my_face_3848.jpg
# 파일 이동 완료 : my_face_2567.jpg
# 파일 이동 완료 : my_face_2040.jpg
# 파일 이동 완료 : my_face_3822.jpg
# 파일 이동 완료 : my_face_4569.jpg
# 파일 이동 완료 : my_face_2830.jpg
# 파일 이동 완료 : my_face_2788.jpg
# 파일 이동 완료 : my_face_3551.jpg
# 파일 이동 완료 : my_face_1856.jpg
# 파일 이동 완료 : my_face_4246.jpg
# 파일 이동 완료 : my_face_879.jpg
# 파일 이동 완료 : my_face_3462.jpg
# 파일 이동 완료 : my_face_4879.jpg
# 파일 이동 완료 : my_face_3005.jpg
# 파일 이동 완료 : my_face_1145.jpg
# 파일 이동 완료 : my_face_2747.jpg
# 파일 이동 완료 : my_face_1301.jpg
# 파일 이동 완료 : my_face_2578.jpg
# 파일 이동 완료 : my_face_2776.jpg
# 파일 이동 완료 : my_face_4138.jpg
# 파일 이동 완료 : my_face_2656.jpg
# 파일 이동 완료 : my_face_859.jpg
# 파일 이동 완료 : my_face_3440.jpg
# 파일 이동 완료 : my_face_4195.jpg
# 파일 이동 완료 : my_face_429.jpg
# 파일 이동 완료 : my_face_351.jpg
# 파일 이동 완료 : my_face_2551.jpg
# 파일 이동 완료 : my_face_3657.jpg
# 파일 이동 완료 : my_face_355.jpg
# 파일 이동 완료 : my_face_4012.jpg
# 파일 이동 완료 : my_face_3521.jpg
# 파일 이동 완료 : my_face_2072.jpg
# 파일 이동 완료 : my_face_1950.jpg
# 파일 이동 완료 : my_face_4580.jpg
# 파일 이동 완료 : my_face_4211.jpg
# 파일 이동 완료 : my_face_3689.jpg
# 파일 이동 완료 : my_face_1439.jpg
# 파일 이동 완료 : my_face_4177.jpg
# 파일 이동 완료 : my_face_2645.jpg
# 파일 이동 완료 : my_face_578.jpg
# 파일 이동 완료 : my_face_2156.jpg
# 파일 이동 완료 : my_face_4600.jpg
# 파일 이동 완료 : my_face_2595.jpg
# 파일 이동 완료 : my_face_1567.jpg
# 파일 이동 완료 : my_face_4982.jpg
# 파일 이동 완료 : my_face_3545.jpg
# 파일 이동 완료 : my_face_676.jpg
# 파일 이동 완료 : my_face_3388.jpg
# 파일 이동 완료 : my_face_2691.jpg
# 파일 이동 완료 : my_face_544.jpg
# 파일 이동 완료 : my_face_4206.jpg
# 파일 이동 완료 : my_face_3731.jpg
# 파일 이동 완료 : my_face_4823.jpg
# 파일 이동 완료 : my_face_2900.jpg
# 파일 이동 완료 : my_face_590.jpg
# 파일 이동 완료 : my_face_3055.jpg
# 파일 이동 완료 : my_face_4163.jpg
# 파일 이동 완료 : my_face_2545.jpg
# 파일 이동 완료 : my_face_3344.jpg
# 파일 이동 완료 : my_face_945.jpg
# 파일 이동 완료 : my_face_2406.jpg
# 파일 이동 완료 : my_face_4611.jpg
# 파일 이동 완료 : Steven_Curtis_Chapman_0001.jpg
# 파일 이동 완료 : Robert_Downey_Jr_0001.jpg
# 파일 이동 완료 : Guillermo_Coria_0002.jpg
# 파일 이동 완료 : Raul_Mondesi_0001.jpg
# 파일 이동 완료 : Scott_McClellan_0003.jpg
# 파일 이동 완료 : Isabella_Rossellini_0003.jpg
# 파일 이동 완료 : Lionel_Chalmers_0001.jpg
# 파일 이동 완료 : Scott_Fawell_0001.jpg
# 파일 이동 완료 : Mikhail_Kasyanov_0004.jpg
# 파일 이동 완료 : Kim_Ryong-sung_0002.jpg
# 파일 이동 완료 : Prince_Harry_0002.jpg
# 파일 이동 완료 : Julianne_Moore_0014.jpg
# 파일 이동 완료 : David_Anderson_0005.jpg
# 파일 이동 완료 : Martha_Martinez_Flores_0001.jpg
# 파일 이동 완료 : Tim_Robbins_0005.jpg
# 파일 이동 완료 : Reese_Witherspoon_0004.jpg
# 파일 이동 완료 : Conrad_Black_0001.jpg
# 파일 이동 완료 : Martin_Torrijos_0001.jpg
# 파일 이동 완료 : Scott_Rudin_0002.jpg
# 파일 이동 완료 : Minnie_Mendoza_0001.jpg
# 파일 이동 완료 : Alvaro_Silva_Calderon_0003.jpg
# 파일 이동 완료 : Antonio_Trillanes_0001.jpg
# 파일 이동 완료 : Lesley_McCulloch_0002.jpg
# 파일 이동 완료 : Colin_Powell_0137.jpg
# 파일 이동 완료 : Michael_Bloomberg_0010.jpg
# 파일 이동 완료 : Elinor_Caplan_0001.jpg
# 파일 이동 완료 : Tony_Blair_0020.jpg
# 파일 이동 완료 : George_W_Bush_0404.jpg
# 파일 이동 완료 : Tung_Chee-hwa_0002.jpg
# 파일 이동 완료 : Hatsui_Hasuike_0001.jpg
# 파일 이동 완료 : Britney_Spears_0005.jpg
# 파일 이동 완료 : John_Stockton_0004.jpg
# 파일 이동 완료 : Shinzo_Abe_0001.jpg
# 파일 이동 완료 : James_Caan_0002.jpg
# 파일 이동 완료 : Dick_Cheney_0008.jpg
# 파일 이동 완료 : Jennifer_Capriati_0034.jpg
# 파일 이동 완료 : Ana_Guevara_0007.jpg
# 파일 이동 완료 : Erwin_Mapasseng_0001.jpg
# 파일 이동 완료 : Edward_Egan_0001.jpg
# 파일 이동 완료 : Nina_Jacobson_0001.jpg
# 파일 이동 완료 : Patti_Lank_0001.jpg
# 파일 이동 완료 : Li_Peng_0004.jpg
# 파일 이동 완료 : Colin_Powell_0149.jpg
# 파일 이동 완료 : Hugo_Chavez_0027.jpg
# 파일 이동 완료 : Ellen_Barkin_0001.jpg
# 파일 이동 완료 : John_Bolton_0014.jpg
# 파일 이동 완료 : Annie_Machon_0001.jpg
# 파일 이동 완료 : Edward_Lu_0002.jpg
# 파일 이동 완료 : Hu_Jintao_0002.jpg
# 파일 이동 완료 : Blythe_Danner_0001.jpg
# 파일 이동 완료 : Gene_Robinson_0003.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0001.jpg
# 파일 이동 완료 : Ariel_Sharon_0010.jpg
# 파일 이동 완료 : Laurent_Jalabert_0001.jpg
# 파일 이동 완료 : Brenda_van_Dam_0001.jpg
# 파일 이동 완료 : Cherie_Blair_0002.jpg
# 파일 이동 완료 : Amelia_Vega_0005.jpg
# 파일 이동 완료 : Joschka_Fischer_0019.jpg
# 파일 이동 완료 : Guillermo_Canas_0001.jpg
# 파일 이동 완료 : Jesus_Cardenal_0001.jpg
# 파일 이동 완료 : Dianne_Feinstein_0002.jpg
# 파일 이동 완료 : Shireen_Amir_Begum_0001.jpg
# 파일 이동 완료 : Joaquim_Rodriguez_0001.jpg
# 파일 이동 완료 : Kim_Jong-Il_0004.jpg
# 파일 이동 완료 : Linda_Franklin_0001.jpg
# 파일 이동 완료 : Alfonso_Soriano_0001.jpg
# 파일 이동 완료 : Tavis_Smiley_0001.jpg
# 파일 이동 완료 : Jeffrey_Immelt_0001.jpg
# 파일 이동 완료 : Edina_Batar_0001.jpg
# 파일 이동 완료 : Kim_Clijsters_0009.jpg
# 파일 이동 완료 : Daisy_Fuentes_0002.jpg
# 파일 이동 완료 : Tim_Duncan_0004.jpg
# 파일 이동 완료 : Jong_Wook_Lee_0001.jpg
# 파일 이동 완료 : Bob_Huggins_0004.jpg
# 파일 이동 완료 : Al_Gore_0003.jpg
# 파일 이동 완료 : Ariel_Sharon_0052.jpg
# 파일 이동 완료 : Roger_Suarez_0001.jpg
# 파일 이동 완료 : Colin_Powell_0120.jpg
# 파일 이동 완료 : Maria_Shriver_0004.jpg
# 파일 이동 완료 : Christine_Rau_0001.jpg
# 파일 이동 완료 : Elin_Nordegren_0002.jpg
# 파일 이동 완료 : Tom_Crean_0005.jpg
# 파일 이동 완료 : Nick_Rahall_0001.jpg
# 파일 이동 완료 : Albert_Costa_0005.jpg
# 파일 이동 완료 : Anna_Nicole_Smith_0001.jpg
# 파일 이동 완료 : Elijah_Wood_0003.jpg
# 파일 이동 완료 : Cora_Cambell_0001.jpg
# 파일 이동 완료 : Andrea_Yates_0001.jpg
# 파일 이동 완료 : Wolfgang_Schwarz_0001.jpg
# 파일 이동 완료 : Vicente_Fox_0004.jpg
# 파일 이동 완료 : Joe_Garner_0001.jpg
# 파일 이동 완료 : Edie_Falco_0001.jpg
# 파일 이동 완료 : Tony_Blair_0116.jpg
# 파일 이동 완료 : Imre_Kertasz_0001.jpg
# 파일 이동 완료 : Pat_Wharton_0001.jpg
# 파일 이동 완료 : Norah_Jones_0010.jpg
# 파일 이동 완료 : Loretta_Lynn_Harper_0001.jpg
# 파일 이동 완료 : Ricardo_Lopez_Murphy_0002.jpg
# 파일 이동 완료 : Syed_Abdul_Rahman_Geelani_0001.jpg
# 파일 이동 완료 : Paul_Reiser_0001.jpg
# 파일 이동 완료 : John_Perrota_0001.jpg
# 파일 이동 완료 : Tom_Ridge_0032.jpg
# 파일 이동 완료 : Jake_Brace_0001.jpg
# 파일 이동 완료 : Christian_Olsson_0001.jpg
# 파일 이동 완료 : Kang_Gum-sil_0001.jpg
# 파일 이동 완료 : Eva_Dimas_0002.jpg
# 파일 이동 완료 : Jose_Serra_0003.jpg
# 파일 이동 완료 : Lyle_Vanclief_0002.jpg
# 파일 이동 완료 : Abdullah_Gul_0008.jpg
# 파일 이동 완료 : Venus_Williams_0006.jpg
# 파일 이동 완료 : Nicanor_Duarte_Frutos_0006.jpg
# 파일 이동 완료 : Lindsay_Benko_0002.jpg
# 파일 이동 완료 : Alvaro_Uribe_0027.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0058.jpg
# 파일 이동 완료 : Jan_Ullrich_0005.jpg
# 파일 이동 완료 : Laurent_Gbagbo_0001.jpg
# 파일 이동 완료 : Tubby_Smith_0002.jpg
# 파일 이동 완료 : Mike_Myers_0006.jpg
# 파일 이동 완료 : Robert_Durst_0001.jpg
# 파일 이동 완료 : Robert_Mueller_0001.jpg
# 파일 이동 완료 : Shawn_Marion_0001.jpg
# 파일 이동 완료 : Carlos_Alberto_0001.jpg
# 파일 이동 완료 : Joe_Carnahan_0001.jpg
# 파일 이동 완료 : Freda_Black_0001.jpg
# 파일 이동 완료 : Colin_Powell_0195.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0010.jpg
# 파일 이동 완료 : Momir_Nikolic_0001.jpg
# 파일 이동 완료 : Jeremy_Greenstock_0024.jpg
# 파일 이동 완료 : Eric_Wedge_0001.jpg
# 파일 이동 완료 : LeBron_James_0003.jpg
# 파일 이동 완료 : Michelle_Pfeiffer_0003.jpg
# 파일 이동 완료 : Charlton_Heston_0003.jpg
# 파일 이동 완료 : Dany_Heatley_0001.jpg
# 파일 이동 완료 : George_W_Bush_0421.jpg
# 파일 이동 완료 : Paul_Bremer_0020.jpg
# 파일 이동 완료 : David_Hasselhoff_0001.jpg
# 파일 이동 완료 : Alastair_Campbell_0001.jpg
# 파일 이동 완료 : Bernard_Law_0003.jpg
# 파일 이동 완료 : Tariq_Aziz_0005.jpg
# 파일 이동 완료 : Jean-Claude_Braquet_0001.jpg
# 파일 이동 완료 : Gwendal_Peizerat_0002.jpg
# 파일 이동 완료 : Bruce_Weber_0002.jpg
# 파일 이동 완료 : Marisol_Martinez_Sambran_0001.jpg
# 파일 이동 완료 : Noer_Muis_0001.jpg
# 파일 이동 완료 : Roh_Moo-hyun_
# 파일 이동 완료 : Tamara_Mowry_0001.jpg
# 파일 이동 완료 : Andy_Bryant_0001.jpg
# 파일 이동 완료 : Tracy_McGrady_0002.jpg
# 파일 이동 완료 : George_Ryan_0001.jpg
# 파일 이동 완료 : George_W_Bush_0258.jpg
# 파일 이동 완료 : James_McMahon_0001.jpg
# 파일 이동 완료 : Joseph_Biden_0004.jpg
# 파일 이동 완료 : Ariel_Sharon_0070.jpg
# 파일 이동 완료 : Richard_Reid_0001.jpg
# 파일 이동 완료 : Gong_Ruina_0001.jpg
# 파일 이동 완료 : Christine_Ebersole_0001.jpg
# 파일 이동 완료 : Ray_Romano_0009.jpg
# 파일 이동 완료 : Tom_Daschle_0023.jpg
# 파일 이동 완료 : Noer_Moeis_0001.jpg
# 파일 이동 완료 : Bode_Miller_0001.jpg
# 파일 이동 완료 : Linda_Mason_0001.jpg
# 파일 이동 완료 : Giuseppe_Gibilisco_0004.jpg
# 파일 이동 완료 : Nan_Wang_0001.jpg
# 파일 이동 완료 : Dan_Bylsma_0001.jpg
# 파일 이동 완료 : Prince_William_0002.jpg
# 파일 이동 완료 : James_Kelly_0004.jpg
# 파일 이동 완료 : Thomas_Rupprath_0001.jpg
# 파일 이동 완료 : Jennifer_Garner_0009.jpg
# 파일 이동 완료 : Kathleen_Kennedy_Townsend_0003.jpg
# 파일 이동 완료 : Joseph_Deiss_0002.jpg
# 파일 이동 완료 : Serena_Williams_0021.jpg
# 파일 이동 완료 : Trent_Lott_0013.jpg
# 파일 이동 완료 : Vicente_Fox_de_la_Concha_0001.jpg
# 파일 이동 완료 : Rachel_Griffiths_0001.jpg
# 파일 이동 완료 : Jean-Rene_Fourtou_0001.jpg
# 파일 이동 완료 : John_Lisowski_0001.jpg
# 파일 이동 완료 : John_Kerry_0015.jpg
# 파일 이동 완료 : Joe_Lieberman_0013.jpg
# 파일 이동 완료 : Augustin_Calleri_0003.jpg
# 파일 이동 완료 : Gavyn_Davies_0001.jpg
# 파일 이동 완료 : George_W_Bush_0129.jpg
# 파일 이동 완료 : Frank_Sinatra_0001.jpg
# 파일 이동 완료 : Stephanie_Cohen_Aloro_0001.jpg
# 파일 이동 완료 : Zahir_Shah_0001.jpg
# 파일 이동 완료 : Norah_Jones_0011.jpg
# 파일 이동 완료 : Pete_Sampras_0005.jpg
# 파일 이동 완료 : Lon_Kruger_0001.jpg
# 파일 이동 완료 : Colin_Farrell_0003.jpg
# 파일 이동 완료 : Tony_Blair_0037.jpg
# 파일 이동 완료 : Malcolm_Wild_0001.jpg
# 파일 이동 완료 : Juan_Carlos_Ferrero_0014.jpg
# 파일 이동 완료 : Amelie_Mauresmo_0014.jpg
# 파일 이동 완료 : Dominique_de_Villepin_0004.jpg
# 파일 이동 완료 : Kim_Dae-jung_0002.jpg
# 파일 이동 완료 : Helen_Clark_0002.jpg
# 파일 이동 완료 : Steve_Pagliuca_0001.jpg
# 파일 이동 완료 : Jamie_Dimon_0001.jpg
# 파일 이동 완료 : Mark_Wahlberg_0003.jpg
# 파일 이동 완료 : Bonnie_Fuller_0001.jpg
# 파일 이동 완료 : Michelle_Chiklis_0001.jpg
# 파일 이동 완료 : Pamela_Anderson_0002.jpg
# 파일 이동 완료 : Carla_Myers_0001.jpg
# 파일 이동 완료 : Franz_Muentefering_0003.jpg
# 파일 이동 완료 : Antony_Leung_0001.jpg
# 파일 이동 완료 : Andre_Agassi_
# 파일 이동 완료 : Megan_Mullally_0002.jpg
# 파일 이동 완료 : Gustavo_Kuerten_0003.jpg
# 파일 이동 완료 : Rhina_Villatoro_0001.jpg
# 파일 이동 완료 : Thaksin_Shinawatra_0001.jpg
# 파일 이동 완료 : Gabriel_Batistuta_0001.jpg
# 파일 이동 완료 : Chuck_Eidson_0001.jpg
# 파일 이동 완료 : Yoko_Ono_0003.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0024.jpg
# 파일 이동 완료 : Miguel_Estrada_0001.jpg
# 파일 이동 완료 : Marco_Pantani_0001.jpg
# 파일 이동 완료 : John_Ashcroft_0004.jpg
# 파일 이동 완료 : Alec_Baldwin_0001.jpg
# 파일 이동 완료 : Curtis_Strange_0001.jpg
# 파일 이동 완료 : Jesse_Harris_0003.jpg
# 파일 이동 완료 : Peter_Harrison_0001.jpg
# 파일 이동 완료 : George_W_Bush_0110.jpg
# 파일 이동 완료 : Martha_Smith_0001.jpg
# 파일 이동 완료 : Mireille_Jospin-Dandieu_0001.jpg
# 파일 이동 완료 : Terry_Gilliam_0001.jpg
# 파일 이동 완료 : Kofi_Annan_0016.jpg
# 파일 이동 완료 : Hitomi_Soga_0005.jpg
# 파일 이동 완료 : Larry_Templeton_0001.jpg
# 파일 이동 완료 : David_Zeplowitz_0001.jpg
# 파일 이동 완료 : Alfredo_Pena_0001.jpg
# 파일 이동 완료 : George_W_Bush_0206.jpg
# 파일 이동 완료 : John_Paul_DeJoria_0001.jpg
# 파일 이동 완료 : Sergei_Ivanov_0005.jpg
# 파일 이동 완료 : Vladimir_Putin_0014.jpg
# 파일 이동 완료 : George_W_Bush_0054.jpg
# 파일 이동 완료 : Thaksin_Shinawatra_0005.jpg
# 파일 이동 완료 : Don_Flanagan_0001.jpg
# 파일 이동 완료 : Colin_Powell_0153.jpg
# 파일 이동 완료 : Terence_Newman_0001.jpg
# 파일 이동 완료 : Jorge_Valdano_0002.jpg
# 파일 이동 완료 : John_Snow_0007.jpg
# 파일 이동 완료 : Joseph_Safra_0001.jpg
# 파일 이동 완료 : Michelle_Collins_0001.jpg
# 파일 이동 완료 : Aaron_Peirsol_0001.jpg
# 파일 이동 완료 : Courtney_Love_0002.jpg
# 파일 이동 완료 : Tony_Stewart_0006.jpg
# 파일 이동 완료 : Roh_Moo-hyun_0006.jpg
# 파일 이동 완료 : Zhu_Rongji_0002.jpg
# 파일 이동 완료 : Lloyd_Ward_0002.jpg
# 파일 이동 완료 : Dexter_Jackson_0002.jpg
# 파일 이동 완료 : Salma_Hayek_0010.jpg
# 파일 이동 완료 : Charlie_Coles_0001.jpg
# 파일 이동 완료 : Tim_Henman_0001.jpg
# 파일 이동 완료 : Dennis_Oswald_0001.jpg
# 파일 이동 완료 : Peter_Ueberroth_0001.jpg
# 파일 이동 완료 : David_Dodge_0002.jpg
# 파일 이동 완료 : Jeremy_Greenstock_0015.jpg
# 파일 이동 완료 : Tom_Daschle_0001.jpg
# 파일 이동 완료 : Dave_Wannstedt_0001.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0022.jpg
# 파일 이동 완료 : Steve_Ballmer_0001.jpg
# 파일 이동 완료 : Yu_Shyi-kun_0002.jpg
# 파일 이동 완료 : William_Ford_Jr_0003.jpg
# 파일 이동 완료 : Suzanne_Gaudet_0001.jpg
# 파일 이동 완료 : Aaron_Sorkin_0002.jpg
# 파일 이동 완료 : Carlos_Savedra_0001.jpg
# 파일 이동 완료 : Gary_Stevens_0001.jpg
# 파일 이동 완료 : Michael_Pfleger_0001.jpg
# 파일 이동 완료 : Vicente_Fox_
0002.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0022.jpg
# 파일 이동 완료 : Jim_Leach_0001.jpg
# 파일 이동 완료 : Mahathir_Mohamad_0005.jpg
# 파일 이동 완료 : George_W_Bush_0483.jpg
# 파일 이동 완료 : Guillermo_Coria_0015.jpg
# 파일 이동 완료 : Felipe_Perez_Roque_0002.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0050.jpg
# 파일 이동 완료 : Alexander_Losyukov_0002.jpg
# 파일 이동 완료 : Gene_Hackman_0001.jpg
# 파일 이동 완료 : Alexis_Bledel_0001.jpg
# 파일 이동 완료 : Serena_Williams_0046.jpg
# 파일 이동 완료 : Pervez_Musharraf_0018.jpg
# 파일 이동 완료 : Nestor_Kirchner_0034.jpg
# 파일 이동 완료 : Tony_Blair_0095.jpg
# 파일 이동 완료 : Bulent_Ecevit_0002.jpg
# 파일 이동 완료 : Venus_Williams_0003.jpg
# 파일 이동 완료 : Paddy_Long_0001.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0018.jpg
# 파일 이동 완료 : Tim_Salmon_0001.jpg
# 파일 이동 완료 : Ion_Iliescu_0001.jpg
# 파일 이동 완료 : Jan_Paul_Miller_0001.jpg
# 파일 이동 완료 : Sanja_Papic_0001.jpg
# 파일 이동 완료 : Vladimir_Putin_0028.jpg
# 파일 이동 완료 : Taha_Yassin_Ramadan_0001.jpg
# 파일 이동 완료 : Alastair_Johnston_0001.jpg
# 파일 이동 완료 : Jiang_Zemin_0011.jpg
# 파일 이동 완료 : Tyler_Grillo_0001.jpg
# 파일 이동 완료 : Robin_Wagner_0001.jpg
# 파일 이동 완료 : Bill_Clinton_0012.jpg
# 파일 이동 완료 : Ari_Fleischer_0008.jpg
# 파일 이동 완료 : Mark_Schweiker_0001.jpg
# 파일 이동 완료 : John_Negroponte_0024.jpg
# 파일 이동 완료 : Edward_Norton_0002.jpg
# 파일 이동 완료 : Tim_Henman_0018.jpg
# 파일 이동 완료 : Todd_Petit_0001.jpg
# 파일 이동 완료 : Luciano_Pavarotti_0003.jpg
# 파일 이동 완료 : Pierre_Lacroix_0001.jpg
# 파일 이동 완료 : Yoriko_Kawaguchi_0003.jpg
# 파일 이동 완료 : Hal_Sutton_0001.jpg
# 파일 이동 완료 : Flavia_Delaroli_0001.jpg
# 파일 이동 완료 : Fazal-ur-Rehman_0001.jpg
# 파일 이동 완료 : Zinedine_Zidane_0005.jpg
# 파일 이동 완료 : George_Brumley_III_0001.jpg
# 파일 이동 완료 : Mariana_Pollack_0001.jpg
# 파일 이동 완료 : Theresa_May_0001.jpg
# 파일 이동 완료 : Jean-Pierre_Bemba_0001.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0001.jpg
# 파일 이동 완료 : Jacques_Chirac_0046.jpg
# 파일 이동 완료 : Jerry_Falwell_0001.jpg
# 파일 이동 완료 : Nicanor_Duarte_Frutos_0009.jpg
# 파일 이동 완료 : Raoul_Ruiz_0002.jpg
# 파일 이동 완료 : Fidel_Castro_0009.jpg
# 파일 이동 완료 : Ashton_Kutcher_0001.jpg
# 파일 이동 완료 : Jamie_Lee_Curtis_0001.jpg
# 파일 이동 완료 : Irfan_Ahmed_0001.jpg
# 파일 이동 완료 : Paula_Locke_0001.jpg
# 파일 이동 완료 : Paula_Zahn_0001.jpg
# 파일 이동 완료 : Halle_Berry_0015.jpg
# 파일 이동 완료 : Ted_Nolan_0001.jpg
# 파일 이동 완료 : Jerry_Regier_0002.jpg
# 파일 이동 완료 : Eladio_Larez_0001.jpg
# 파일 이동 완료 : Ivo_Dubs_0001.jpg
# 파일 이동 완료 : Jolanta_Kwasniewski_0001.jpg
# 파일 이동 완료 : Imad_Moustapha_0002.jpg
# 파일 이동 완료 : Alec_Baldwin_0002.jpg
# 파일 이동 완료 : Andre_Agassi_0030.jpg
# 파일 이동 완료 : Mel_Gibson_0001.jpg
# 파일 이동 완료 : Rudolph_Giuliani_0020.jpg
# 파일 이동 완료 : Bertie_Ahern_0001.jpg
# 파일 이동 완료 : Salma_Hayek_0001.jpg
# 파일 이동 완료 : Laurence_Fishburne_0001.jpg
# 파일 이동 완료 : Jeremy_Greenstock_0006.jpg
# 파일 이동 완료 : Bill_Richardson_0001.jpg
# 파일 이동 완료 : Evgeni_Plushenko_0001.jpg
# 파일 이동 완료 : Nestor_Kirchner_0007.jpg
# 파일 이동 완료 : Marina_Anissina_0002.jpg
# 파일 이동 완료 : Oscar_De_La_Hoya_0005.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0022.jpg
# 파일 이동 완료 : Cedric_Benson_0001.jpg
# 파일 이동 완료 : Jason_Sorens_0001.jpg
# 파일 이동 완료 : Ari_Bousbib_0001.jpg
# 파일 이동 완료 : Charlie_Hunnam_0001.jpg
# 파일 이동 완료 : Clint_Eastwood_0004.jpg
# 파일 이동 완료 : Amy_Brenneman_0001.jpg
# 파일 이동 완료 : Mary_Robinson_0001.jpg
# 파일 이동 완료 : Gunter_Pleuger_0006.jpg
# 파일 이동 완료 : Steve_Lavin_0002.jpg
# 파일 이동 완료 : Joey_Mantia_0001.jpg
# 파일 이동 완료 : Joe_Lieberman_0003.jpg
# 파일 이동 완료 : Chakib_Khelil_0001.jpg
# 파일 이동 완료 : Maryn_McKenna_0001.jpg
# 파일 이동 완료 : David_Duval_0001.jpg
# 파일 이동 완료 : Chris_Dodd_0001.jpg
# 파일 이동 완료 : Kate_Hudson_0001.jpg
# 파일 이동 완료 : Zafarullah_Khan_Jamali_0002.jpg
# 파일 이동 완료 : Ann_Veneman_0010.jpg
# 파일 이동 완료 : Jean_Brumley_0001.jpg
# 파일 이동 완료 : Samantha_Ledster_0001.jpg
# 파일 이동 완료 : Kim_Yong-il_0002.jpg
# 파일 이동 완료 : Steve_Allee_0001.jpg
# 파일 이동 완료 : Lee_Chang-dong_0001.jpg
# 파일 이동 완료 : Vicente_Fox_0005.jpg
# 파일 이동 완료 : Muammar_Gaddafi_0002.jpg
# 파일 이동 완료 : Marian_Dolan_0001.jpg
# 파일 이동 완료 : Rob_Niedermayer_0001.jpg
# 파일 이동 완료 : Kofi_Annan_0027.jpg
# 파일 이동 완료 : Colin_Powell_0145.jpg
# 파일 이동 완료 : Jack_Grubman_0001.jpg
# 파일 이동 완료 : Seymour_Cassell_0001.jpg
# 파일 이동 완료 : Abdullah_Gul_0012.jpg
# 파일 이동 완료 : Gabriella_Bo_0001.jpg
# 파일 이동 완료 : Jorma_Huhtala_0001.jpg
# 파일 이동 완료 : Bob_Huggins_0003.jpg
# 파일 이동 완료 : Gabriel_Jorge_Ferreia_0001.jpg
# 파일 이동 완료 : John_Snow_0009.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0011.jpg
# 파일 이동 완료 : Carla_Sullivan_0001.jpg
# 파일 이동 완료 : Rebecca_Romijn-Stamos_0001.jpg
# 파일 이동 완료 : Wayne_Ferreira_0003.jpg
# 파일 이동 완료 : Alejandro_Fernandez_0001.jpg
# 파일 이동 완료 : George_W_Bush_0361.jpg
# 파일 이동 완료 : Emmanuelle_Beart_0003.jpg
# 파일 이동 완료 : Jacques_Rogge_0006.jpg
# 파일 이동 완료 : Ashanti_0002.jpg
# 파일 이동 완료 : Jean-Pierre_Raffarin_0006.jpg
# 파일 이동 완료 : Tom_Ridge_0025.jpg
# 파일 이동 완료 : Hannah_Stockbauer_0001.jpg
# 파일 이동 완료 : Nanni_Moretti_0001.jpg
# 파일 이동 완료 : John_Allen_Muhammad_0009.jpg
# 파일 이동 완료 : Robert_Bonner_0003.jpg
# 파일 이동 완료 : Sadam_Hassan_0001.jpg
# 파일 이동 완료 : Saeed_Mortazavi_0001.jpg
# 파일 이동 완료 : Steve_Largent_0001.jpg
# 파일 이동 완료 : Lyle_Vanclief_0001.jpg
# 파일 이동 완료 : Gonzalo_Sanchez_de_Lozada_0001.jpg
# 파일 이동 완료 : Colin_Powell_0092.jpg
# 파일 이동 완료 : Dave_Matthews_0001.jpg
# 파일 이동 완료 : Raoul_Ruiz_0004.jpg
# 파일 이동 완료 : Natasha_McElhone_0003.jpg
# 파일 이동 완료 : Jacques_Chirac_0040.jpg
# 파일 이동 완료 : Alfred_Ford_0001.jpg
# 파일 이동 완료 : Princess_Caroline_0003.jpg
# 파일 이동 완료 : Alexandra_Stevenson_0001.jpg
# 파일 이동 완료 : Jean_Charest_0011.jpg
# 파일 이동 완료 : Fred_Rogers_0001.jpg
# 파일 이동 완료 : Bill_Graham_0004.jpg
# 파일 이동 완료 : Laurel_Clark_0001.jpg
# 파일 이동 완료 : Placido_Domingo_0001.jpg
# 파일 이동 완료 : Tony_Blair_0032.jpg
# 파일 이동 완료 : Helo_Pinheiro_0001.jpg
# 파일 이동 완료 : Luis_Figo_0001.jpg
# 파일 이동 완료 : Richard_Virenque_0001.jpg
# 파일 이동 완료 : George_W_Bush_0014.jpg
# 파일 이동 완료 : Gunter_Pleuger_0004.jpg
# 파일 이동 완료 : Alvaro_Uribe_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0066.jpg
# 파일 이동 완료 : Ralf_Schumacher_0003.jpg
# 파일 이동 완료 : Guillermo_Coria_0010.jpg
# 파일 이동 완료 : Brandon_Knight_0001.jpg
# 파일 이동 완료 : George_W_Bush_0485.jpg
# 파일 이동 완료 : Glenn_Tilton_0001.jpg
# 파일 이동 완료 : Jamling_Norgay_0001.jpg
# 파일 이동 완료 : Alan_Greenspan_0001.jpg
# 파일 이동 완료 : Bill_Simon_0014.jpg
# 파일 이동 완료 : Jean_Chretien_0015.jpg
# 파일 이동 완료 : Ralf_Schumacher_0008.jpg
# 파일 이동 완료 : Pete_Sampras_0022.jpg
# 파일 이동 완료 : Sarah_Michelle_Gellar_0003.jpg
# 파일 이동 완료 : Anna_Kournikova_0007.jpg
# 파일 이동 완료 : James_Harris_0001.jpg
# 파일 이동 완료 : Janet_Napolitano_0001.jpg
# 파일 이동 완료 : Doug_Duncan_0002.jpg
# 파일 이동 완료 : Jacques_Chirac_0033.jpg
# 파일 이동 완료 : Daniele_Bergamin_0001.jpg
# 파일 이동 완료 : LeBron_James_0004.jpg
# 파일 이동 완료 : Dawn_Staley_0001.jpg
# 파일 이동 완료 : Tony_Blair_0033.jpg
# 파일 이동 완료 : Andy_Graves_0001.jpg
# 파일 이동 완료 : Sarah_Hughes_0005.jpg
# 파일 이동 완료 : Katja_Riemann_0001.jpg
# 파일 이동 완료 : Li_Zhaoxing_0007.jpg
# 파일 이동 완료 : Charlie_Sheen_0001.jpg
# 파일 이동 완료 : Laura_Bush_0025.jpg
# 파일 이동 완료 : Natalia_Vodonova_0001.jpg
# 파일 이동 완료 : Jean-Claude_Juncker_0001.jpg
# 파일 이동 완료 : Ruth_Christofferson_0001.jpg
# 파일 이동 완료 : William_Cocksedge_0001.jpg
# 파일 이동 완료 : Tony_Blair_0143.jpg
# 파일 이동 완료 : Jose_Maria_Aznar_0012.jpg
# 파일 이동 완료 : Lindsay_Davenport_0015.jpg
# 파일 이동 완료 : Richard_Hamilton_0001.jpg
# 파일 이동 완료 : Allyson_Felix_0005.jpg
# 파일 이동 완료 : Lee_Soo-hyuck_0002.jpg
# 파일 이동 완료 : Mario_Lemieux_0001.jpg
# 파일 이동 완료 : Winona_Ryder_0011.jpg
# 파일 이동 완료 : Hama_Arba_Diallo_0001.jpg
# 파일 이동 완료 : Kim_Dae-jung_0007.jpg
# 파일 이동 완료 : George_W_Bush_0369.jpg
# 파일 이동 완료 : Fernando_Alonso_0001.jpg
# 파일 이동 완료 : Joan_Jett_0001.jpg
# 파일 이동 완료 : Serena_Williams_0026.jpg
# 파일 이동 완료 : Muwafak_al-Ani_0001.jpg
# 파일 이동 완료 : Eloy_Gutierrez_0001.jpg
# 파일 이동 완료 : Colin_Powell_0142.jpg
# 파일 이동 완료 : Rio_Ferdinand_0002.jpg
# 파일 이동 완료 : Milo_Maestrecampo_0003.jpg
# 파일 이동 완료 : Sean_OKeefe_0003.jpg
# 파일 이동 완료 : Gray_Davis_0018.jpg
# 파일 이동 완료 : Gary_Gero_0001.jpg
# 파일 이동 완료 : Keith_Tyson_0001.jpg
# 파일 이동 완료 : James_Gandolfini_0001.jpg
# 파일 이동 완료 : Bernice_Wong_0001.jpg
# 파일 이동 완료 : Fujio_Cho_0003.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0010.jpg
# 파일 이동 완료 : John_Ashcroft_0003.jpg
# 파일 이동 완료 : Antonio_Palocci_0006.jpg
# 파일 이동 완료 : Rebekah_Chantay_Revels_0003.jpg
# 파일 이동 완료 : Biljana_Plavsic_0001.jpg
# 파일 이동 완료 : Maureen_Kanka_0001.jpg
# 파일 이동 완료 : Ekke_Hard_Forberg_0001.jpg
# 파일 이동 완료 : Wolfgang_Becker_0001.jpg
# 파일 이동 완료 : Jo_Joong-hyon_0001.jpg
# 파일 이동 완료 : George_Maxwell_Richards_0001.jpg
# 파일 이동 완료 : Linda_Baboolal_0001.jpg
# 파일 이동 완료 : Kweisi_Mfume_0001.jpg
# 파일 이동 완료 : Kofi_Annan_0010.jpg
# 파일 이동 완료 : Paul_Wellstone_0003.jpg
# 파일 이동 완료 : Don_Lake_0001.jpg
# 파일 이동 완료 : Suk_Chung_Hong_0001.jpg
# 파일 이동 완료 : Mike_Babcock_0001.jpg
# 파일 이동 완료 : Jiri_Novak_0007.jpg
# 파일 이동 완료 : Tim_Henman_0004.jpg
# 파일 이동 완료 : Princess_Masako_0001.jpg
# 파일 이동 완료 : James_Kelly_0006.jpg
# 파일 이동 완료 : Roger_Lyons_0001.jpg
# 파일 이동 완료 : Saddam_Hussein_
jpg
# 파일 이동 완료 : Mahmoud_Abbas_0001.jpg
# 파일 이동 완료 : Sebastien_Grosjean_0002.jpg
# 파일 이동 완료 : Ahmet_Necdet_Sezer_0001.jpg
# 파일 이동 완료 : David_Hyde_Pierce_0004.jpg
# 파일 이동 완료 : Katrin_Susi_0001.jpg
# 파일 이동 완료 : Xiang_Xu_0001.jpg
# 파일 이동 완료 : Sadie_Frost_0001.jpg
# 파일 이동 완료 : Tom_Hanks_0007.jpg
# 파일 이동 완료 : Kim_Jong-Il_0001.jpg
# 파일 이동 완료 : Urmila_Matondkar_0001.jpg
# 파일 이동 완료 : Alejandro_Toledo_0008.jpg
# 파일 이동 완료 : Rick_Pitino_0003.jpg
# 파일 이동 완료 : Trent_Lott_0016.jpg
# 파일 이동 완료 : Edward_Burns_0001.jpg
# 파일 이동 완료 : Paul_Farley_0001.jpg
# 파일 이동 완료 : Dennis_Miller_0001.jpg
# 파일 이동 완료 : George_W_Bush_0082.jpg
# 파일 이동 완료 : Larry_Johnson_0002.jpg
# 파일 이동 완료 : Nicolas_Eyzaguirre_0001.jpg
# 파일 이동 완료 : Lene_Espersen_0001.jpg
# 파일 이동 완료 : Helen_Clark_0003.jpg
# 파일 이동 완료 : Tom_Craddick_0002.jpg
# 파일 이동 완료 : Ariel_Sharon_0006.jpg
# 파일 이동 완료 : Dorothy_Lamour_0001.jpg
# 파일 이동 완료 : Tom_Cruise_0006.jpg
# 파일 이동 완료 : James_Morris_0001.jpg
# 파일 이동 완료 : Eduard_Shevardnadze_0004.jpg
# 파일 이동 완료 : Inga_Hall_0001.jpg
# 파일 이동 완료 : Beth_Blough_0001.jpg
# 파일 이동 완료 : Herb_Sendek_0002.jpg
# 파일 이동 완료 : John_Paul_II_0006.jpg
# 파일 이동 완료 : Bob_Stoops_0001.jpg
# 파일 이동 완료 : George_W_Bush_0411.jpg
# 파일 이동 완료 : Arnaud_Clement_0001.jpg
# 파일 이동 완료 : Li_Peng_0009.jpg
# 파일 이동 완료 : Jean_Todt_0001.jpg
# 파일 이동 완료 : Dustan_Mohr_0001.jpg
# 파일 이동 완료 : George_W_Bush_0410.jpg
# 파일 이동 완료 : Albert_Pujols_0001.jpg
# 파일 이동 완료 : Tom_Ridge_0027.jpg
# 파일 이동 완료 : Elton_John_0001.jpg
# 파일 이동 완료 : Owen_Nolan_0001.jpg
# 파일 이동 완료 : Martin_Verkerk_0003.jpg
# 파일 이동 완료 : John_Ashcroft_0051.jpg
# 파일 이동 완료 : Leander_Paes_0001.jpg
# 파일 이동 완료 : George_W_Bush_0278.jpg
# 파일 이동 완료 : Rafael_Vinoly_0001.jpg
# 파일 이동 완료 : Rolandas_Paksas_0002.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0025.jpg
# 파일 이동 완료 : Chris_Swecker_0001.jpg
# 파일 이동 완료 : Art_Hoffmann_0002.jpg
# 파일 이동 완료 : Pedro_Almodovar_0005.jpg
# 파일 이동 완료 : Billy_Edelin_0001.jpg
# 파일 이동 완료 : George_P_Bush_0002.jpg
# 파일 이동 완료 : Tony_Bennett_0001.jpg
# 파일 이동 완료 : GL_Peiris_0003.jpg
# 파일 이동 완료 : Condoleezza_Rice_0008.jpg
# 파일 이동 완료 : Nikki_Teasley_0001.jpg
# 파일 이동 완료 : Ximena_Bohorquez_0001.jpg
# 파일 이동 완료 : Tony_Blair_0053.jpg
# 파일 이동 완료 : Jiang_Zemin_0004.jpg
# 파일 이동 완료 : Kelly_Clarkson_0001.jpg
# 파일 이동 완료 : George_W_Bush_0349.jpg
# 파일 이동 완료 : Mary_Lou_Markakis_0001.jpg
# 파일 이동 완료 : Frank_Solich_0003.jpg
# 파일 이동 완료 : Terrell_Suggs_0001.jpg
# 파일 이동 완료 : George_Galloway_0003.jpg
# 파일 이동 완료 : Kenny_Chesney_0001.jpg
# 파일 이동 완료 : James_Blake_0011.jpg
# 파일 이동 완료 : Jean_Chretien_0030.jpg
# 파일 이동 완료 : Ariel_Sharon_0054.jpg
# 파일 이동 완료 : Taha_Yassin_Ramadan_0013.jpg
# 파일 이동 완료 : Paul_Martin_0008.jpg
# 파일 이동 완료 : Howard_Ross_0001.jpg
# 파일 이동 완료 : Mia_Mottley_0001.jpg
# 파일 이동 완료 : George_W_Bush_0435.jpg
# 파일 이동 완료 : Antony_Leung_0004.jpg
# 파일 이동 완료 : Jean-Marc_Olive_0001.jpg
# 파일 이동 완료 : Nestor_Kirchner_0008.jpg
# 파일 이동 완료 : John_Kerry_0008.jpg
# 파일 이동 완료 : Rolf_Eckrodt_0001.jpg
# 파일 이동 완료 : Jessica_Lynch_0002.jpg
# 파일 이동 완료 : Shimon_Peres_0002.jpg
# 파일 이동 완료 : Andre_Agassi_0022.jpg
# 파일 이동 완료 : Ben_Betts_0001.jpg
# 파일 이동 완료 : Robert_Altman_0001.jpg
# 파일 이동 완료 : Didier_Defago_0001.jpg
# 파일 이동 완료 : Saparmurat_Niyazov_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0038.jpg
# 파일 이동 완료 : Ruth_Dreifuss_0002.jpg
# 파일 이동 완료 : Ilan_Ramon_0002.jpg
# 파일 이동 완료 : Anthony_Pico_0001.jpg
# 파일 이동 완료 : Nelson_Mandela_0002.jpg
# 파일 이동 완료 : Kristanna_Loken_0001.jpg
# 파일 이동 완료 : Ana_Claudia_Talancon_0001.jpg
# 파일 이동 완료 : Vincent_Brooks_0005.jpg
# 파일 이동 완료 : Bill_Clinton_0003.jpg
# 파일 이동 완료 : Jennifer_McCoy_0001.jpg
# 파일 이동 완료 : Gordon_Brown_0002.jpg
# 파일 이동 완료 : Rick_Lu_0001.jpg
# 파일 이동 완료 : Lindsay_Davenport_0016.jpg
# 파일 이동 완료 : Sonya_Walger_0001.jpg
# 파일 이동 완료 : George_W_Bush_0477.jpg
# 파일 이동 완료 : Adrien_Brody_0008.jpg
# 파일 이동 완료 : Holly_Hunter_0007.jpg
# 파일 이동 완료 : Keanu_Reeves_0009.jpg
# 파일 이동 완료 : George_W_Bush_0314.jpg
# 파일 이동 완료 : George_W_Bush_0425.jpg
# 파일 이동 완료 : David_Alpay_0001.jpg
# 파일 이동 완료 : Ahmad_Masood_0001.jpg
# 파일 이동 완료 : Mukesh_Ambani_0003.jpg
# 파일 이동 완료 : Bill_Clinton_0001.jpg
# 파일 이동 완료 : Patrick_Leahy_0002.jpg
# 파일 이동 완료 : Jean_Chretien_0019.jpg
# 파일 이동 완료 : Mariah_Carey_0005.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0018.jpg
# 파일 이동 완료 : Malik_Mahmud_0001.jpg
# 파일 이동 완료 : Kevin_Costner_0006.jpg
# 파일 이동 완료 : Thor_Pedersen_0001.jpg
# 파일 이동 완료 : Michelle_Rodriguez_0002.jpg
# 파일 이동 완료 : Ronald_Brower_0001.jpg
# 파일 이동 완료 : Matt_Dillon_0003.jpg
# 파일 이동 완료 : Mohammad_Khatami_0005.jpg
# 파일 이동 완료 : James_Butts_0001.jpg
# 파일 이동 완료 : Tom_Ridge_0030.jpg
# 파일 이동 완료 : Juan_Carlos_Ferrero_0024.jpg
# 파일 이동 완료 : Jim_Carrey_0001.jpg
# 파일 이동 완료 : Anne_Donovan_0001.jpg
# 파일 이동 완료 : Alejandro_Toledo_0026.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0017.jpg
# 파일 이동 완료 : Uma_Thurman_0001.jpg
# 파일 이동 완료 : Jelena_Dokic_0002.jpg
# 파일 이동 완료 : Nestor_Kirchner_0014.jpg
# 파일 이동 완료 : Jan_Petersen_0001.jpg
# 파일 이동 완료 : David_Wells_0004.jpg
# 파일 이동 완료 : Bill_Clinton_0015.jpg
# 파일 이동 완료 : Paul_Kelleher_0001.jpg
# 파일 이동 완료 : Tony_Blair_0128.jpg
# 파일 이동 완료 : Hans_Blix_0039.jpg
# 파일 이동 완료 : Vincent_Sombrotto_0001.jpg
# 파일 이동 완료 : Brenda_Wilson_0001.jpg
# 파일 이동 완료 : Rita_Grande_0001.jpg
# 파일 이동 완료 : Gerard_Tronche_0001.jpg
# 파일 이동 완료 : Gerard_Depardieu_0001.jpg
# 파일 이동 완료 : Sergei_Ivanov_0003.jpg
# 파일 이동 완료 : Jack_Valenti_0001.jpg
# 파일 이동 완료 : Saddam_Hussein_0007.jpg
# 파일 이동 완료 : Calvin_Harrison_0001.jpg
# 파일 이동 완료 : Heidi_Fleiss_0004.jpg
# 파일 이동 완료 : Joxel_Garcia_0001.jpg
# 파일 이동 완료 : Ken_Kutaragi_0001.jpg
# 파일 이동 완료 : George_W_Bush_0476.jpg
# 파일 이동 완료 : Carlos_Queiroz_0001.jpg
# 파일 이동 완료 : Rina_Lazo_0001.jpg
# 파일 이동 완료 : Michael_Bloomberg_0004.jpg
# 파일 이동 완료 : James_Cameron_0003.jpg
# 파일 이동 완료 : Rick_Romley_0001.jpg
# 파일 이동 완료 : Jesse_Jackson_0006.jpg
# 파일 이동 완료 : Geoff_Hoon_0004.jpg
# 파일 이동 완료 : Pervez_Musharraf_0012.jpg
# 파일 이동 완료 : Andy_Perez_0001.jpg
# 파일 이동 완료 : Colin_Powell_0047.jpg
# 파일 이동 완료 : Hans_Eichel_0003.jpg
# 파일 이동 완료 : Laura_Bush_0038.jpg
# 파일 이동 완료 : George_W_Bush_0367.jpg
# 파일 이동 완료 : Hussam_Mohammed_Amin_0001.jpg
# 파일 이동 완료 : Farouk_Kaddoumi_0001.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0005.jpg
# 파일 이동 완료 : George_W_Bush_0520.jpg
# 파일 이동 완료 : Susie_Castillo_0002.jpg
# 파일 이동 완료 : Carrie-Anne_Moss_0003.jpg
# 파일 이동 완료 : Alvaro_Noboa_0001.jpg
# 파일 이동 완료 : Duane_Lee_Chapman_0001.jpg
# 파일 이동 완료 : Peter_OToole_0001.jpg
# 파일 이동 완료 : Tian_Liang_0001.jpg
# 파일 이동 완료 : Roy_Moore_0001.jpg
# 파일 이동 완료 : Vladimir_Putin_
0001.jpg
# 파일 이동 완료 : Nestor_Kirchner_0024.jpg
# 파일 이동 완료 : Mike_Weir_0003.jpg
# 파일 이동 완료 : Timothy_Wirth_0001.jpg
# 파일 이동 완료 : Rogelio_Montemayor_0001.jpg
# 파일 이동 완료 : Ari_Fleischer_0001.jpg
# 파일 이동 완료 : Jane_Riley_0001.jpg
# 파일 이동 완료 : Angelo_Genova_0001.jpg
# 파일 이동 완료 : John_Ashcroft_0011.jpg
# 파일 이동 완료 : John_Reilly_0002.jpg
# 파일 이동 완료 : Tiger_Woods_0006.jpg
# 파일 이동 완료 : Ali_Abbas_0001.jpg
# 파일 이동 완료 : George_W_Bush_0298.jpg
# 파일 이동 완료 : Abdullah_Ahmad_Badawi_0001.jpg
# 파일 이동 완료 : Joan_Collins_0001.jpg
# 파일 이동 완료 : Mohammad_Khatami_0007.jpg
# 파일 이동 완료 : Julianne_Moore_0013.jpg
# 파일 이동 완료 : Jennifer_Aniston_0006.jpg
# 파일 이동 완료 : Pedro_Malan_0005.jpg
# 파일 이동 완료 : George_W_Bush_0036.jpg
# 파일 이동 완료 : Elsa_Zylberstein_0006.jpg
# 파일 이동 완료 : Roy_Chaderton_0001.jpg
# 파일 이동 완료 : Natalie_Maines_0003.jpg
# 파일 이동 완료 : Hugo_Chavez_0037.jpg
# 파일 이동 완료 : Priscilla_Presley_0002.jpg
# 파일 이동 완료 : Frank_Cassell_0003.jpg
# 파일 이동 완료 : Caio_Blat_0001.jpg
# 파일 이동 완료 : Ozzie_Smith_0001.jpg
# 파일 이동 완료 : Lindsay_Davenport_0022.jpg
# 파일 이동 완료 : Tommy_Franks_0015.jpg
# 파일 이동 완료 : Mark_Philippoussis_0011.jpg
# 파일 이동 완료 : Tomomi_Morita_0001.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0003.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0034.jpg
# 파일 이동 완료 : Stefan_Tafrov_0001.jpg
# 파일 이동 완료 : Jeremy_Greenstock_0012.jpg
# 파일 이동 완료 : Thomas_Bjorn_0002.jpg
# 파일 이동 완료 : Emma_Thompson_0002.jpg
# 파일 이동 완료 : Kathryn_Grayson_0001.jpg
# 파일 이동 완료 : Michel_Duclos_0002.jpg
# 파일 이동 완료 : Dario_Franchitti_0001.jpg
# 파일 이동 완료 : Milo_Djukanovic_0003.jpg
# 파일 이동 완료 : George_W_Bush_0497.jpg
# 파일 이동 완료 : Renee_Zellweger_0016.jpg
# 파일 이동 완료 : Tommy_Thompson_0008.jpg
# 파일 이동 완료 : Carlos_Moya_0013.jpg
# 파일 이동 완료 : Taufik_Hidayat_0001.jpg
# 파일 이동 완료 : Saddam_Hussein_0012.jpg
# 파일 이동 완료 : Alvaro_Uribe_0024.jpg
# 파일 이동 완료 : Klaus_Zwickel_0002.jpg
# 파일 이동 완료 : Tom_Crean_0002.jpg
# 파일 이동 완료 : George_W_Bush_0473.jpg
# 파일 이동 완료 : Laila_Ali_0003.jpg
# 파일 이동 완료 : Alexander_Downer_0001.jpg
# 파일 이동 완료 : Mara_Georges_0001.jpg
# 파일 이동 완료 : Britney_Spears_0001.jpg
# 파일 이동 완료 : Lane_Odom_0001.jpg
# 파일 이동 완료 : Chris_Matthews_0001.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0034.jpg
# 파일 이동 완료 : David_Trimble_0003.jpg
# 파일 이동 완료 : Laura_Linney_0003.jpg
# 파일 이동 완료 : Tom_Ridge_0011.jpg
# 파일 이동 완료 : Joe_Torre_0002.jpg
# 파일 이동 완료 : Nick_Reilly_0001.jpg
# 파일 이동 완료 : Spencer_Abraham_0007.jpg
# 파일 이동 완료 : Nicoletta_Braschi_0001.jpg
# 파일 이동 완료 : Himmler_Rebu_0001.jpg
# 파일 이동 완료 : Alicia_Keys_0001.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0007.jpg
# 파일 이동 완료 : Wang_Yingfan_0001.jpg
# 파일 이동 완료 : Francisco_Flores_0001.jpg
# 파일 이동 완료 : Mark_Podlesny_0001.jpg
# 파일 이동 완료 : Natalie_Juniardi_0001.jpg
# 파일 이동 완료 : Marty_Mornhinweg_0001.jpg
# 파일 이동 완료 : Natasha_McElhone_0001.jpg
# 파일 이동 완료 : Hans_Blix_0028.jpg
# 파일 이동 완료 : Andrew_Sabey_0001.jpg
# 파일 이동 완료 : Ciro_Gomes_0003.jpg
# 파일 이동 완료 : Nicholas_Tse_0002.jpg
# 파일 이동 완료 : Robert_Mugabe_0001.jpg
# 파일 이동 완료 : Philippe_Noiret_0002.jpg
# 파일 이동 완료 : Donald_Hays_0001.jpg
# 파일 이동 완료 : George_HW_Bush_0002.jpg
# 파일 이동 완료 : Natalia_Motuziuk_0001.jpg
# 파일 이동 완료 : Celia_Cruz_0001.jpg
# 파일 이동 완료 : James_Parker_0002.jpg
# 파일 이동 완료 : Ariel_Sharon_0048.jpg
# 파일 이동 완료 : Andy_Roddick_0007.jpg
# 파일 이동 완료 : Candie_Kung_0003.jpg
# 파일 이동 완료 : Afton_Smith_0001.jpg
# 파일 이동 완료 : James_Franco_0002.jpg
# 파일 이동 완료 : Colin_Powell_0231.jpg
# 파일 이동 완료 : Peter_Camejo_0001.jpg
# 파일 이동 완료 : Gwyneth_Paltrow_0003.jpg
# 파일 이동 완료 : Heinz_Feldmann_0003.jpg
# 파일 이동 완료 : Patrick_Coleman_0001.jpg
# 파일 이동 완료 : Queen_Sofia_0001.jpg
# 파일 이동 완료 : Hamzah_Haz_0002.jpg
# 파일 이동 완료 : Norah_Jones_0015.jpg
# 파일 이동 완료 : George_W_Bush_0205.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0024.jpg
# 파일 이동 완료 : Eva_Marie_Saint_0001.jpg
# 파일 이동 완료 : Joe_Calzaghe_0001.jpg
# 파일 이동 완료 : James_Wolfensohn_0005.jpg
# 파일 이동 완료 : Greg_Owen_0002.jpg
# 파일 이동 완료 : Ekaterina_Dmitriev_0001.jpg
# 파일 이동 완료 : Vladimir_Spidla_0002.jpg
# 파일 이동 완료 : David_Nalbandian_0001.jpg
# 파일 이동 완료 : Carroll_Weimer_0001.jpg
# 파일 이동 완료 : Li_Peng_0008.jpg
# 파일 이동 완료 : Joschka_Fischer_0009.jpg

# %%
print('Training data의 my_face 이미지 수 : ', len(os.listdir('/content/tr_data/my')))
print('Training data의 other_face 이미지 수 : ', len(os.listdir('/content/tr_data/other')))

print('Test data의 my_face 이미지 수 : ', len(os.listdir('/content/te_data/my')))
print('Test data의 other_face 이미지 수 : ', len(os.listdir('/content/te_data/other')))
# Out:
# Training data의 my_face 이미지 수 :  3836
# Training data의 other_face 이미지 수 :  3836
# Test data의 my_face 이미지 수 :  960
# Test data의 other_face 이미지 수 :  960

# %% [markdown]
# #### 2) **특정 함수** 사용

# %%
## Training set 데이터 폴더를 데이터셋화
## 이 과정에서 Validation set도 생성
tr_idfd, val_idfd = image_dataset_from_directory(tr_data,                    ## Training 폴더 경로
                                                 class_names=['other','my'], ## 클래스 순서 지정
                                                 batch_size=32,              ## 이미지 덩어리 단위
                                                 image_size=(160,160),       ## 이미지 리사이즈
                                                 shuffle=True,               ## 섞어야 올바르게 분할됨
                                                 seed=2024,                  ## 재현성
                                                 validation_split=0.2,       ## 데이터 스플릿 비율
                                                 subset='both',              ## 데이터셋 나눔 방식
                                                 )
# Out:
# Found 7672 files belonging to 2 classes.
# Using 6138 files for training.
# Using 1534 files for validation.

# %%
## Test set 데이터 폴더를 데이터셋화
te_idfd = image_dataset_from_directory(te_data,                    ## Test 폴더 경로
                                       class_names=['other','my'], ## 클래스 순서 지정
                                       batch_size=32,              ## 이미지 덩어리 단위
                                       image_size=(160,160),       ## 이미지 리사이즈
                                       shuffle=True,               ## 섞어야 올바르게 분할됨
                                       seed=2024                   ## 재현성
                                       )
# Out:
# Found 1920 files belonging to 2 classes.

# %%
## 위에서 만든 이미지 데이터 덩어리가 몇 개인지 확인
len(tr_idfd), len(val_idfd), len(te_idfd)
# Out:
# (192, 48, 60)

# %%
192*32, 48*32, 60*32
# Out:
# (6144, 1536, 1920)

# %%
tr_idfd
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# #### 3) 스케일링

# %%
def rescale(image, label) :
    image = image / 255
    return image, label

# %%
tr_idfd_rescale = tr_idfd.map(rescale)
val_idfd_rescale = val_idfd.map(rescale)
te_idfd_rescale = te_idfd.map(rescale)

# %% [markdown]
# ## 4.미션2

# %% [markdown]
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (1) FaceNet 구조 생성

# %% [markdown]
# * **세부 요구사항**
#     - FaceNet의 구조를 생성합니다.
#         - FaceNet 구조 생성에 필요한 함수를 만듭니다.
#     - FaceNet의 구조에 **잘 학습된 가중치**를 부여합니다.
#         - FaceNet 원본 가중치 파일을 공유하였습니다.
#     - (선택사항) FaceNet 모델의 가중치 업데이트를 방지합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - numpy, functools, keras

# %% [markdown]
# #### 1) 모델 구조 생성

# %%
import numpy as np
from functools import partial


import keras
from keras.models import Model

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Activation
from keras.layers import BatchNormalization, Dropout, GlobalAveragePooling2D
from keras.layers import Lambda, Concatenate, add

from keras import backend as K
from keras.saving import register_keras_serializable

# %%
## 3.6.0.dev2024102803 OK
keras.__version__
# Out:
# '3.7.0.dev2024102803'

# %%
@register_keras_serializable()
def scaling(x, scale):
    return x * scale

@register_keras_serializable()
def conv2d_bn(x,
              filters,
              kernel_size,
              strides=1,
              padding='same',
              activation='relu',
              use_bias=False,
              name=None):
    x = Conv2D(filters,
               kernel_size,
               strides=strides,
               padding=padding,
               use_bias=use_bias,
               name=name)(x)
    if not use_bias:
        bn_axis = 1 if K.image_data_format() == 'channels_first' else 3
        bn_name = _generate_layer_name('BatchNorm', prefix=name)
        x = BatchNormalization(axis=bn_axis, momentum=0.995, epsilon=0.001,
                               scale=False, name=bn_name)(x)
    if activation is not None:
        ac_name = _generate_layer_name('Activation', prefix=name)
        x = Activation(activation, name=ac_name)(x)
    return x

@register_keras_serializable()
def _generate_layer_name(name, branch_idx=None, prefix=None):
    if prefix is None:
        return None
    if branch_idx is None:
        return '_'.join((prefix, name))
    return '_'.join((prefix, 'Branch', str(branch_idx), name))

@register_keras_serializable()
def _inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    if block_idx is None:
        prefix = None
    else:
        prefix = '_'.join((block_type, str(block_idx)))
    name_fmt = partial(_generate_layer_name, prefix=prefix)

    if block_type == 'Block35':
        branch_0 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 32, 3, name=name_fmt('Conv2d_0b_3x3', 1))
        branch_2 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0b_3x3', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0c_3x3', 2))
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'Block17':
        branch_0 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 128, [1, 7], name=name_fmt('Conv2d_0b_1x7', 1))
        branch_1 = conv2d_bn(branch_1, 128, [7, 1], name=name_fmt('Conv2d_0c_7x1', 1))
        branches = [branch_0, branch_1]
    elif block_type == 'Block8':
        branch_0 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 192, [1, 3], name=name_fmt('Conv2d_0b_1x3', 1))
        branch_1 = conv2d_bn(branch_1, 192, [3, 1], name=name_fmt('Conv2d_0c_3x1', 1))
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "Block35", "Block17" or "Block8", '
                         'but got: ' + str(block_type))

    mixed = Concatenate(axis=channel_axis, name=name_fmt('Concatenate'))(branches)
    up = conv2d_bn(mixed,
                #    K.int_shape(x)[channel_axis],
                   x.shape[channel_axis],
                   1,
                   activation=None,
                   use_bias=True,
                   name=name_fmt('Conv2d_1x1'))
    up = Lambda(scaling,
                # output_shape=K.int_shape(up)[1:],
                output_shape=up.shape[1:],
                arguments={'scale': scale})(up)
    x = add([x, up])
    if activation is not None:
        x = Activation(activation, name=name_fmt('Activation'))(x)
    return x

# %%
@register_keras_serializable()
def InceptionResNetV1(input_shape=(160, 160, 3),
                      classes=128,
                      dropout_keep_prob=0.8,
                      weights_path=None):
    inputs = Input(shape=input_shape)
    x = conv2d_bn(inputs, 32, 3, strides=2, padding='valid', name='Conv2d_1a_3x3')
    x = conv2d_bn(x, 32, 3, padding='valid', name='Conv2d_2a_3x3')
    x = conv2d_bn(x, 64, 3, name='Conv2d_2b_3x3')
    x = MaxPooling2D(3, strides=2, name='MaxPool_3a_3x3')(x)
    x = conv2d_bn(x, 80, 1, padding='valid', name='Conv2d_3b_1x1')
    x = conv2d_bn(x, 192, 3, padding='valid', name='Conv2d_4a_3x3')
    x = conv2d_bn(x, 256, 3, strides=2, padding='valid', name='Conv2d_4b_3x3')

    # 5x Block35 (Inception-ResNet-A block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.17,
                                    block_type='Block35',
                                    block_idx=block_idx)

    # Mixed 6a (Reduction-A block):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    name_fmt = partial(_generate_layer_name, prefix='Mixed_6a')
    branch_0 = conv2d_bn(x,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1, 192, 3, name=name_fmt('Conv2d_0b_3x3', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 2))(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_6a')(branches)

    # 10x Block17 (Inception-ResNet-B block):
    for block_idx in range(1, 11):
        x = _inception_resnet_block(x,
                                    scale=0.1,
                                    block_type='Block17',
                                    block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    name_fmt = partial(_generate_layer_name, prefix='Mixed_7a')
    branch_0 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 0))
    branch_0 = conv2d_bn(branch_0,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_2 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 2))
    branch_2 = conv2d_bn(branch_2, 256, 3, name=name_fmt('Conv2d_0b_3x3', 2))
    branch_2 = conv2d_bn(branch_2,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 2))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 3))(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_7a')(branches)

    # 5x Block8 (Inception-ResNet-C block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.2,
                                    block_type='Block8',
                                    block_idx=block_idx)
    x = _inception_resnet_block(x,
                                scale=1.,
                                activation=None,
                                block_type='Block8',
                                block_idx=6)

    # Classification block
    x = GlobalAveragePooling2D(name='AvgPool')(x)
    x = Dropout(1.0 - dropout_keep_prob, name='Dropout')(x)
    # Bottleneck
    x = Dense(classes, use_bias=False, name='Bottleneck')(x)
    bn_name = _generate_layer_name('BatchNorm', prefix='Bottleneck')
    x = BatchNormalization(momentum=0.995, epsilon=0.001, scale=False,
                           name=bn_name)(x)

    # Create model
    model = Model(inputs, x, name='inception_resnet_v1')
    if weights_path is not None:
        model.load_weights(weights_path)

    return model

# %%
## FaceNet 구조 생성 코드
facenet_model = InceptionResNetV1()

# %%
## FaceNet 구조의 전체 레이어 길이
len(facenet_model.layers)
# Out:
# 447

# %%
## FaceNet 전체 구조 확인
facenet_model.summary()
# Out:
# Model: "inception_resnet_v1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 160, 160, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3 (Conv2D)    │ (None, 79, 79, 32)     │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_BatchNorm   │ (None, 79, 79, 32)     │             96 │ Conv2d_1a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_Activation  │ (None, 79, 79, 32)     │              0 │ Conv2d_1a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3 (Conv2D)    │ (None, 77, 77, 32)     │          9,216 │ Conv2d_1a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_BatchNorm   │ (None, 77, 77, 32)     │             96 │ Conv2d_2a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_Activation  │ (None, 77, 77, 32)     │              0 │ Conv2d_2a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3 (Conv2D)    │ (None, 77, 77, 64)     │         18,432 │ Conv2d_2a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_BatchNorm   │ (None, 77, 77, 64)     │            192 │ Conv2d_2b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_Activation  │ (None, 77, 77, 64)     │              0 │ Conv2d_2b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ MaxPool_3a_3x3            │ (None, 38, 38, 64)     │              0 │ Conv2d_2b_3x3_Activat… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1 (Conv2D)    │ (None, 38, 38, 80)     │          5,120 │ MaxPool_3a_3x3[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_BatchNorm   │ (None, 38, 38, 80)     │            240 │ Conv2d_3b_1x1[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_Activation  │ (None, 38, 38, 80)     │              0 │ Conv2d_3b_1x1_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3 (Conv2D)    │ (None, 36, 36, 192)    │        138,240 │ Conv2d_3b_1x1_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_BatchNorm   │ (None, 36, 36, 192)    │            576 │ Conv2d_4a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_Activation  │ (None, 36, 36, 192)    │              0 │ Conv2d_4a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3 (Conv2D)    │ (None, 17, 17, 256)    │        442,368 │ Conv2d_4a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_BatchNorm   │ (None, 17, 17, 256)    │            768 │ Conv2d_4b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_Activation  │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_1_Branch_1_Co… │
# │                           │                        │                │ Block35_1_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 17, 17, 256)    │              0 │ Block35_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_Activat… │
# │                           │                        │                │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Activation      │ (None, 17, 17, 256)    │              0 │ add[0][0]              │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_2_Branch_1_Co… │
# │                           │                        │                │ Block35_2_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_2_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_2_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_1_Activation[… │
# │                           │                        │                │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Activation      │ (None, 17, 17, 256)    │              0 │ add_1[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_3_Branch_1_Co… │
# │                           │                        │                │ Block35_3_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_3_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_3_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_2_Activation[… │
# │                           │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Activation      │ (None, 17, 17, 256)    │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_4_Branch_1_Co… │
# │                           │                        │                │ Block35_4_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_4_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_4_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_3_Activation[… │
# │                           │                        │                │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Activation      │ (None, 17, 17, 256)    │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_5_Branch_1_Co… │
# │                           │                        │                │ Block35_5_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_5_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_5_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_4_Activation[… │
# │                           │                        │                │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Activation      │ (None, 17, 17, 256)    │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │         49,152 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │        331,776 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │        884,736 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │        442,368 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │          1,152 │ Mixed_6a_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │            768 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │              0 │ Mixed_6a_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_2_MaxPoo… │ (None, 8, 8, 256)      │              0 │ Block35_5_Activation[… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a (Concatenate)    │ (None, 8, 8, 896)      │              0 │ Mixed_6a_Branch_0_Con… │
# │                           │                        │                │ Mixed_6a_Branch_1_Con… │
# │                           │                        │                │ Mixed_6a_Branch_2_Max… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Concatenate     │ (None, 8, 8, 256)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block17_1_Branch_1_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Conv2d_1x1      │ (None, 8, 8, 896)      │        230,272 │ Block17_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 8, 8, 896)      │              0 │ Block17_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 8, 8, 896)      │              0 │ Mixed_6a[0][0],        │
# │                           │                        │                │ lambda_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Activation      │ (None, 8, 8, 896)      │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ add_17 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_2_Activation[0… │
# │                           │                        │                │ lambda_17[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_3_Activation       │ (None, 3, 3, 1792)     │              0 │ add_17[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_4_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_4_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_18 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_4_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_3_Activation[0… │
# │                           │                        │                │ lambda_18[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Activation       │ (None, 3, 3, 1792)     │              0 │ add_18[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_5_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_5_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_19 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_5_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_4_Activation[0… │
# │                           │                        │                │ lambda_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Activation       │ (None, 3, 3, 1792)     │              0 │ add_19[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_6_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_6_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_20 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_6_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_20 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_5_Activation[0… │
# │                           │                        │                │ lambda_20[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ AvgPool                   │ (None, 1792)           │              0 │ add_20[0][0]           │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Dropout (Dropout)         │ (None, 1792)           │              0 │ AvgPool[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck (Dense)        │ (None, 128)            │        229,376 │ Dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck_BatchNorm      │ (None, 128)            │            384 │ Bottleneck[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 22,808,144 (87.01 MB)
#  Trainable params: 22,779,312 (86.90 MB)
#  Non-trainable params: 28,832 (112.62 KB)

# %%
from keras.utils import plot_model

# %%
plot_model(facenet_model, show_shapes=True, show_layer_activations=True, show_trainable=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### 2) 모델에 가중치 적용

# %%
## FaceNet 가중치 파일 경로 설정
weights_path = path + '/Keras/facenet_model_weights.npz'
weights_path
# Out:
# '/content/drive/MyDrive/project4/Keras/facenet_model_weights.npz'

# %%
## 가중치 파일 불러오기
loaded_weights = np.load(weights_path)

loaded_weights
# Out:
# NpzFile '/content/drive/MyDrive/project4/Keras/facenet_model_weights.npz' with keys: arr_0, arr_1, arr_2, arr_3, arr_4...

# %%
## FaceNet 각 레이어에 가중치 적용
facenet_model.set_weights([loaded_weights[key] for key in loaded_weights])

# %% [markdown]
# #### 3) 모델의 가중치 업데이트 방지 (선택사항)

# %%
## FaceNet 전체 레이어에서 마지막 4개의 레이어 확인
facenet_model.layers[-2:]
# Out:
# [<Dense name=Bottleneck, built=True>,
#  <BatchNormalization name=Bottleneck_BatchNorm, built=True>]

# %%
## FaceNet 전체 레이어에서 마지막 4개의 레이어에만 가중치 업데이트 적용
for l in facenet_model.layers[:-2] :
    l.trainable = False

# %% [markdown]
# ### (2) 모델 구조 변형

# %% [markdown]
# * **세부 요구사항**
#     - 우리의 문제에 맞게 모델을 변형해야 합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 추가 모델링

# %%
## FaceNet 모델에 이진 분류용 레이어 하나 추가
K.clear_session()

custom_model = keras.models.Sequential()

custom_model.add(facenet_model)
custom_model.add(Dense(1, activation='sigmoid') )

# %%
custom_model.summary() ## keras-nightly로는 정상 작동
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ inception_resnet_v1 (Functional)     │ (None, 128)                 │      22,808,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,808,273 (87.01 MB)
#  Trainable params: 229,633 (897.00 KB)
#  Non-trainable params: 22,578,640 (86.13 MB)

# %%
custom_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy', 'precision', 'recall']
                     )

# %% [markdown]
# ## 5.미션3

# %% [markdown]
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ### (1) 모델 학습

# %% [markdown]
# * **세부 요구사항**
#     - 모델 구조를 잘 변형하였다면, 학습도 진행해야 합니다.
#         - Keras에서 지원하는 다양한 함수를 사용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 학습에 유용한 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %%
## 얼리스토핑 설정
es = EarlyStopping(patience=3, verbose=1, restore_best_weights=True)

# %% [markdown]
# #### 2) 모델 학습

# %%
## 모델 학습
custom_model.fit(tr_idfd_rescale, validation_data=val_idfd_rescale,
                 epochs=1000, verbose=1,
                 callbacks=[es]
                 )
# Out:
# Epoch 1/1000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 51s 162ms/step - accuracy: 0.9696 - loss: 0.0613 - precision: 0.9649 - recall: 0.9747 - val_accuracy: 1.0000 - val_loss: 0.0030 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 2/1000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 12s 60ms/step - accuracy: 0.9990 - loss: 0.0045 - precision: 1.0000 - recall: 0.9980 - val_accuracy: 1.0000 - val_loss: 6.1094e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 3/1000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - accuracy: 0.9995 - loss: 0.0027 - precision: 1.0000 - recall: 0.9990 - val_accuracy: 1.0000 - val_loss: 1.6942e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 4/1000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 0.9995 - loss: 0.0018 - precision: 0.9996 - recall: 0.9994 - val_accuracy: 1.0000 - val_loss: 1.3247e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 5/1000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 19s 64ms/step - accuracy: 0.9997 - loss: 8.8929e-04 - precision: 1.0000 - recall: 0.9994 - val_accuracy: 1.0000 - val_loss: 2.4821e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 6/1000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 18s 52ms/step - accuracy: 0.9995 - loss: 0.0023 - precision: 1.0000 - recall: 0.9991 - val_accuracy: 1.0000 - val_loss: 1.7725e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 7/1000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 13s 68ms/step - accuracy: 1.0000 - loss: 4.9889e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_loss: 3.9670e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 8/1000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - accuracy: 1.0000 - loss: 2.4640e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_loss: 3.2640e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %% [markdown]
# ### (2) 모델 추론

# %% [markdown]
# * **세부 요구사항**
#     - 학습된 모델의 성능을 확인해보세요.
#         - 임계값 조절, 클래스 가중치 부여 등으로 모델의 성능을 높여보세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras, sklearn

# %% [markdown]
# #### 1) 모델 추론

# %%
## image_dataset_from_directory로 만든 Test set로 예측값 생성
y_pred = custom_model.predict(te_idfd_rescale)
y_pred
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step
# array([[9.9999976e-01],
#        [5.0039475e-06],
#        [1.2639559e-05],
#        ...,
#        [7.9857550e-08],
#        [2.6089656e-05],
#        [8.4376444e-07]], dtype=float32)

# %%
## 예측값에 대한 임계값을 0.5로 설정하여 0과 1로 구분
y_pred_fix = np.where(y_pred>=0.5, 1, 0)
y_pred_fix = y_pred_fix.flatten()
y_pred_fix
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
len(y_pred_fix.nonzero()[0])
# Out:
# 960

# %% [markdown]
# #### 2) 성능 확인

# %%
from sklearn.metrics import classification_report

# %%
## 성능 확인을 위하여 Test set의 Y만 떼와 array로 저장
temp = []

for te_x, te_y in te_idfd :
    temp.append(te_y.numpy())

y_true = np.concatenate(temp)

# %%
len(y_true.nonzero()[0])
# Out:
# 960

# %%
print(classification_report(y_true, y_pred_fix, target_names=['other', 'my']) )
# Out:
#               precision    recall  f1-score   support
#
#        other       0.49      0.49      0.49       960
#           my       0.49      0.49      0.49       960
#
#     accuracy                           0.49      1920
#    macro avg       0.49      0.49      0.49      1920
# weighted avg       0.49      0.49      0.49      1920

# %% [markdown]
# ### (3) 모델 저장

# %% [markdown]
# * **세부 요구사항**
#     - **반드시 반드시 모델을 저장하고 로컬에 다운로드하세요.**
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 모델 저장

# %%
## .keras로 저장해야 안전
custom_model.save('FaceNet_1029.keras')

# %% [markdown]
# #### 2) 저장된 모델 체크

# %%
## Colab에 저장된 모델을 불러와 확인
temp_model = keras.saving.load_model('./FaceNet_1028.keras')
temp_model.summary()
